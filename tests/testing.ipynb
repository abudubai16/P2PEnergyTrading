# %%
a=['a', 'b', 's', 'd']

# %%
{k:{} for k in a}
# Out:
# {'a': {}, 'b': {}, 's': {}, 'd': {}}

# %%
t={'a':{}}

# %%
t['a']['what']=1
t
# Out:
# {'a': {'what': 1}}

# %%
import numpy as np

# %%
a=np.random.randn(10)
a
# Out:
# array([ 0.96721934, -0.83395396, -0.95008508,  0.06904127,  0.91721528,
#         0.98392167, -1.26656874,  0.05650989, -1.19206229,  1.38920369])

# %%
np.sum(np.where(a>0, a, 0))
# Out:
# np.float64(4.383111132971118)

# %%
np.sum(np.where(a<0, -a, 0))
# Out:
# np.float64(4.242670074471064)

# %%
np.std(a)
# Out:
# np.float64(0.9645788350867958)
