# %%
from fy_project.env.market import IEXMarket

# %%
import numpy as np
from datetime import datetime, timedelta

# %%
a= datetime(2025, 1, 1)
b=datetime(2026, 1, 1)
(b-a).days
# Out:
# 365

# %%
np.ones(24, dtype=np.float32).shape
# Out:
# (24,)

# %%
date = datetime(2024, 1, 1, 0)
date
# Out:
# datetime.datetime(2024, 1, 1, 0, 0)

# %%
date= date - timedelta(days=1)
date
# Out:
# datetime.datetime(2023, 12, 26, 0, 0)

# %%
market = IEXMarket()
# Out:
# C:\Users\Abhyuday Chauhan\projects\FY_project\src\fy_project\IEX_data\iex_hourly_market.csv

# %%
market.reset(datetime(2024, 1, 1, 0))

# %%
market.get_day_price(datetime(2024, 1, 2, 0))
# Out:
# [2.988281037460907,
#  2.695648949725652,
#  2.4924891610052327,
#  2.636441224111412,
#  2.7119638629928193,
#  3.100371678950665,
#  4.011487103581913,
#  8.680030723551345,
#  10.0,
#  10.000000000000002,
#  9.542528719999998,
#  7.020651833589272,
#  4.230242326196298,
#  3.487588610806682,
#  3.703965186288357,
#  4.130739145573591,
#  7.70182509052174,
#  10.0,
#  10.0,
#  10.0,
#  5.13691493964541,
#  3.388307319282633,
#  2.9847005514536225,
#  3.100385564120332]

# %%
import pandas as pd

# %%
len(pd.read_csv(r'C:\Users\Abhyuday Chauhan\projects\FY_project\src\fy_project\IEX_data\iex_hourly_market.csv'))
# Out:
# 17544

# %%
731-31
# Out:
# 700
