# %%
import numpy as np
import json

# %%
with open(r'C:\Users\Abhyuday Chauhan\projects\FY_project\weather_cache\Bangalore_2024.json', 'r') as f:
    data = json.load(f)

# %%
vals = []
for i in data:
    vals.append(data[i]['ghi'])

# %%
vals = np.array(vals)
vals.max()
# Out:
# np.float64(1070.35)

# %%
a = np.array([1, 2., 3])
a
# Out:
# array([1., 2., 3.])

# %%
type(a.mean())
# Out:
# numpy.float64

# %%
type(np.sum(a))
# Out:
# numpy.float64

# %%
import wandb

# %%
wandb.Table
