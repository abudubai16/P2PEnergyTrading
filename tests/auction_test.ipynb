# %% [markdown]
# # Auction Logic test

# %%
from fy_project.env.market import AuctionMarket, IEXMarketV2

# %%
import numpy as np
from datetime import datetime

# %%
agents = ["agent1", "agent2", "agent3"]
market = IEXMarketV2()
auction = AuctionMarket(agents=agents, num_bg_orders=40, k=10)
# Out:
# C:\Users\Abhyuday Chauhan\projects\FY_project\src\fy_project\IEX_data\iex_daily_market.csv

# %%
date = datetime(2024, 3, 5)
market.reset(start_date = date)

# %%
val = market.get_day_values(dt = date)

# %%
val
# Out:
# {'price': array([3.1880856, 3.1510594, 2.9669838, 2.8874369, 3.0388157, 3.5226903,
#         3.7864337, 4.7074175, 4.0643077, 3.8820024, 3.2665126, 3.3200006,
#         3.1680512, 2.9018075, 3.1887486, 3.3686552, 3.6494985, 3.5795095,
#         4.1978736, 4.491439 , 3.9456246, 3.6524317, 3.5472834, 3.4356282],
#        dtype=float32),
#  'volume': array([19142.03, 22032.13, 22280.24, 22589.12, 21343.83, 17289.09,
#         22946.7 , 25133.28, 24809.59, 24214.78, 19713.69, 20459.81,
#         19303.12, 18698.07, 18065.79, 20188.98, 22338.57, 21460.71,
#         22974.1 , 19663.5 , 19072.05, 19175.4 , 16004.73, 16236.2 ],
#        dtype=float32)}

# %%
q = {agent: np.random.randn(24)*10 for agent in agents}
p = {agent: np.random.rand(24)*10 for agent in agents}

# %%
values = auction.clear_auction(q, p, val['price'], val['volume'])

# %%
values[0]['agent1']
# Out:
# array([  0.       ,   0.       ,  13.99018  ,   4.911594 ,   0.       ,
#          1.0841358,   7.4346075,   0.       ,   8.435753 ,   3.9881442,
#          1.6386352,   0.       ,   6.3776016,   5.764208 ,   9.055682 ,
#          0.       ,   1.746219 , -12.996955 ,   0.       ,   0.       ,
#          0.       ,   3.291553 ,  11.184899 ,   0.       ], dtype=float32)
